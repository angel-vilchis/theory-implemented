# %% [markdown]
# # Undersampling

# %% [markdown]
# ## NearMiss

# %%
import numpy as np

# %%
class NearMiss:
    def __init__(self, version=1, k):
        self.version = version
        self.X = None
        self.y = None
    
    def fit(self, X, y):
        values, counts = np.unique(y, return_counts=True)
        majority_class = values[np.argmax(counts)]

# %%
from Scratch.helpers.GetDatasets import clustering_split
X_train, X_test, y_train, y_test = clustering_split(n_samples=[50,100], centers=None, cluster_std=[2,5])

# %%
import matplotlib.pyplot as plt
plt.scatter(X_train[:,0], X_train[:,1], c=y_train)

# %%
model = NearMiss()
model.fit(X_train, y_train)

# %%
import matplotlib.pyplot as plt
plt.scatter(model.X[:,0], model.X[:,1], c=model.y)
